# %% [markdown]
# # Die Absoluten Basics (Recap)
#
# **Alle die bereits einen Python Kurs bei mir gemacht haben und / oder sich mit Jupyter Notebooks wie diesem auskennen, können zum nächsten Block springen.**
#
# Das hier ist eine Wiederholung / Einführung in die Nutzeroberfläche von Jupyter Notebooks. Sie soll euch helfen schnell (wieder) mit dem Setup vertraut zu werden. Wenn du bereits mit Python & Jupyter Notebooks vertraut bist, kannst du diesen Abschnitt gerne schneller durchgehen oder ihn ganz überspringen.

# %% [markdown]
# ## Layout
# Dieses Tutorial ist in einem sogenannten Jupyter-Notebook (Dateityp .ipynb) angelegt. Es enthält zwei Arten von "Zellen":
# - Markdown-Zellen (wie diese hier) enthalten Text und Anweisungen
# - Code-Zellen (siehe unten) enthalten... nun ja... Code. Du kannst sie ausführen, indem du auf ein kleines Dreieck klickst oder in sie hinein klickst und SHIFT+ENTER oder CTRL+ENTER drückst.
#
# Was schön an Jupyter Notebooks ist, ist dass Markdown-Zellen es uns ermöglichen, Code einfach zu erklären, aber noch wichtiger ist, dass jede Code-Zelle individuell ausgeführt werden kann. Auf diese Weise kannst du deinen Code Stück für Stück schreiben und testen, deine Ausgabe (oder Fehlermeldung) sofort sehen. Das ermöglicht uns, einfach zu debuggen und zu lernen.
#
# **Probiere es aus, indem du den Codeblock unten ausführst.**

# %%
print("Willkommen zur ersten praktischen Übung im Kurs 'Python für Fortgeschrittene - Datenanalyse, Visualisierung und Statistik in Python!'")

# %% [markdown]
# Du wirst die gedruckte Ausgabe unterhalb der Code-Zelle sehen.
#
# **Verwende die leere Zelle unten, um die print-Funktion selbst auszuprobieren.**

# %% [markdown]
# ## Variablen definieren
#
# Python - und alle anderen Programmiersprachen - verlassen sich auf Variablen oder "Objekte" für Berechnungen. Vereinfacht ausgedrückt hat jede Variable einen *Wert* und einen *Typ*. In Python wird der Typ implizit abgeleitet, was es zu einer zugänglicheren Sprache für Anfänger macht, da du den Datentyp jedes Objekts nicht explizit angeben musst.
#
# Im Folgenden definieren wir zwei Variablen `a` und `b`.
#
# - `a` ist eine *ganze Zahl* mit dem Wert 5
# - `b` ist ein *String* (=Text) mit dem Wert "sieben".
#
# **Führe die untenstehenden Zellen aus**

# %%
a = 5
b = "seven"

# %% [markdown]
# ## Variablen abrufen
#
# Wir haben nun die Werte 5 und "sieben" in die Variablen `a` und `b` gespeichert. Diese gespeicherten Variablen können wir abrufen, indem wir sie *aufrufen*.
#
# **Führe die Zelle unten aus, um `a` aufzurufen und dessen Wert auf dem Bildschirm anzuzeigen.**
#
# (Hinweis: Standardmäßig führt Jupyter den gesamten Code in deiner Codezelle aus, zeigt dir jedoch nur die letzte Variable oder Ausgabe an, es sei denn, du verwendest explizit `print()`.)

# %%
a

# %% [markdown]
# Jetzt möchten wir auch die Variable `b` aufrufen.
#
# **Erstelle eine neue Code-Zelle direkt unter dieser und rufe die Variable `b` auf.**
#
# Du kannst neue Zellen erstellen, indem du auf die Plus-Schaltfläche auf dem Bildschirm klickst.

# %% [markdown]
# Wir können neue Variablen basierend auf bereits zuvor definierten Variablen definieren. Zum Beispiel können wir c = a + 10 definieren.

# %%
c = a + 10
c

# %% [markdown]
# Gut gemacht! 🥳 Du hast dich nun mit den Grundlagen der Jupyter-Benutzeroberfläche vertraut gemacht und weißt, wie man Variablen definiert.

# %% [markdown]
# ## Umgang mit Fehlern
# Python ist vielleicht eine verzeihende Programmiersprache, aber es ist dennoch eine Programmiersprache. Das bedeutet, wenn du seine Regeln nicht befolgst, gibt es einen Fehler zurück und führt deinen Code nicht aus.
#
# Das kann knifflig sein, wenn man anfängt, denn schon ein einziger Tippfehler kann dazu führen, dass dein Code nicht funktioniert. Glücklicherweise gibt Python einige Hinweise darauf, warum dein Code fehlgeschlagen ist. Also, wenn du auf einen Fehler stößt, versuche diese Schritte zu befolgen:
# - Entspanne dich. Fehler passieren die ganze Zeit, sogar den Besten von uns.
# - Lies die Fehlermeldung (besonders der Anfang und das Ende der Meldung liefern hilfreiche Hinweise).
# - Versuche, die Ursache des Fehlers zu lokalisieren
#   - Manchmal sagt dir die Fehlermeldung vielleicht etwas
#   - Manchmal musst du einfach genau hinsehen
#   - Manchmal kann es hilfreich sein, eine komplexere Abfolge von Schritten auseinanderzunehmen, um genau zu sehen, wo dein Code fehlschlägt
# - Wenn du den Code nicht selbst reparieren kannst, dann ist Stackoverflow.com dein Freund. Gib deinen Fehler bei Google ein und schau, welche Ratschläge du auf Stackoverflow bekommst. Jeder macht das.
# - In letzter Zeit ist auch ChatGPT ein ausgezeichnetes Debugging-Werkzeug geworden. Du kannst Code einfügen, es bitten zu erklären, was jede Zeile macht, oder es deinen Code automatisch korrigieren lassen.
#   - Aber beachte, während es großartig ist, Code mit ChatGPT zu schreiben, stelle sicher, dass du nicht einfach nur kopierst und einfügst, sondern versuche tatsächlich zu verstehen, was den Code funktionieren lässt und was nicht.
# - Wenn alles andere fehlschlägt, versuche, eine andere Person um Hilfe zu bitten. Manchmal reicht schon ein frischer Blick.
#
# **Jetzt sieh nach, was mit dem folgenden Code falsch ist und behebe den Fehler.**

# %%
print("This is a really important message. Unfortunately, it won't execute.)

# %% [markdown]
# Lass uns ein etwas kniffligeres Beispiel versuchen. Erinnerst du dich an deine Variablen `a` und `b`, die du oben definiert hast?
#
# **Rufe sie erneut auf, um dich an ihre Werte zu erinnern.**

# %% [markdown]
# **Definiere jetzt die Variable `d = a + b`.**
#
# Warum wird sie nicht ausgeführt? Was kannst du tun, um das Problem zu beheben?

# %% [markdown]
# ### Verwenden von Code-Kommentaren
# Manchmal ist es hilfreich, kleine Notizen in deinem Code zu schreiben, um zu erklären, was passiert. Um dies zu tun, tippe "#" am Anfang deiner Zeile. Solche Zeilen werden nicht als Code ausgeführt.

# %%
# This line is just a comment and will not be executed
print("This line will be printed")

# %% [markdown]
# Du kannst auch Kommentare verwenden, um ganze Codeblöcke auszukommentieren.
# Das kann auch beim Debuggen hilfreich sein.

# %%
#print("Line 1")
#print("Line 2")
print("Line 3")
#print("Line 4")

# %% [markdown]
# ## Juhu! 🥳🎉
# Du hast die grundlegenden Schritte gemeistert. Lass uns jetzt etwas Interessanteres machen, jetzt wo du dich eingelebt hast.

# %% [markdown]
# # Explorative Datenanalyse
# Wir werden uns den Anfängen der explorativen Datenanalyse widmen und lernen wie wir deskriptive Statistiken einer Variable sowie eine Korrelation zwischen zwei Variablen berechnen können.
#
# *Hinweis*: Dieser Kurse ist für fortgeschrittene Nutzer konzipiert. Er setzt voraus, dass du bereits mit den Grundlagen von Python, insbesondere `pandas` vertraut bist. Solltest du nicht wissen wie man mit `pandas` Spalten auswählt und Datensätze filtert, empfehle ich dir, erstmal einen unserer Grundlagenkurse zu besuchen. Möchtest du trotzdem mitmachen, so können dir KI-Assistent wie ChatGPT oder Google Gemini an Stellen helfen, an denen du Schwierigkeiten hast.

# %% [markdown]
# ## Einlesen von Daten
# Wir nutzen zur Übung [diese Daten](https://www.kaggle.com/datasets/steve1215rogg/student-lifestyle-dataset) von Kaggle. Ich habe noch eine weitere Spalte ergänzt.
#
# **Lies die Datei `"01_student_lifestyle.csv"` ein.**
#
# Bedenke, dass du die Datei erst im Ordnerbereich (links) hochladen musst. Die Datei muss dafür entpackt werden (=keine ZIP Datei). Es gibt ein kurzes Demovideo bei den Kursmaterialien auf GitHub, falls du damit Schwierigkeiten hast.

# %%
import ... # Dein Code hier

# %%
df = # Dein Code hier

# %% [markdown]
# **Mache dich kurz mit dem Dataframe vertraut**

# %%
# Dein Code hier

# %% [markdown]
# ## Deskriptive Statistiken
# Wenn wir Daten analysieren, sind wir oft an der Verteilung bestimmter Variablen interessiert. Ein einfaches Maß dafür bieten die deskriptiven Statistiken wie Mittelwert, Minimum, Maximum, Quantile, etc.
#
# Beispielsweise wollen wir den durchschnittlichen Warenkorbwert unserer e-commerce Kunden herausfinden, das frühste Tores unserer Lieblingsmannschaft oder die 1% besten Filme in einer Datenbank.
#
# Die meisten dieser deskriptiven Statistiken können nur auf **numerische Variablen** angewandt werden. Für **kategorische und ordinale** Variablen bietet sich vor allem der Modalwert an, der die Häufigste Ausprägung ausgibt.

# %% [markdown]
# ### Minimum und Maximum
# Selbsterklärend. Gilt für numerische und ordinale Variablen.

# %% [markdown]
# Wir können herausfinden wie fleißig die fleißsigsten und "faulsten" Studenten in unserem Sample sind.

# %%
df.Study_Hours_Per_Day.max()

# %%
df.Study_Hours_Per_Day.min()

# %% [markdown]
# Wollen wir wissen, welcher Zeile die Werte zugehören, nutzeen wir `idxmax()` und `idxmin()` um uns den **Index**, das heißt Identifier der Zeile ausgeben zu lassen.

# %%
df.Study_Hours_Per_Day.idxmax()

# %%
# So sieht das leben des fleißigsten Studenten aus.
# Kein Wunder, dass er gestresst ist, bei 10 Stunden lernen am Tag ;)
df.iloc[100]

# %% [markdown]
# **Probiere die Funktionen für eine andere Spalte deiner Wahl aus**

# %%
# Dein Code hier

# %% [markdown]
# ### Durchschnitte
# Wir haben oben gelernt die Extrema der Verteilung zu bestimmen. Jetzt lernen wir die Mitte der Verteilung kennen.
#
# Viele von euch denken beim Durchschnitt an den Mittelwert. Es gibt aber noch weitere Durchschnitte die bei der Datenanalyse sinnvoll sind: Median und Modalwert.
#
# Eine kurze Erklärung:
# - **Mittelwert**: Summe aller Werte geteilt durch die Anzahl der summierten Werte. Auch arithmetisches Mittel genannt. Anfällig für Ausreißer. Gilt nur für numerische Variablen
# - **Median**: Der Wert für welchen gilt, dass die Hälfte der Beobachtungen oberhalb und die andere Hälfte unterhalb liegt. Wird nicht durch ausreißer verzerrt. Gilt für ordinale und numerische Variablen, sinnvoller für numerische.
# - **Modalwert**: Gibt die am häufigsten vorkommende Beobachtung zurück. Kann im Gegensatz zu den oberen beiden auch auf kategorische Variablen angewandt werden. Gilt für alle Variablen, sinnvoller für kategorische & ordinale.

# %%
df.Study_Hours_Per_Day.mean()

# %%
df.Study_Hours_Per_Day.median()

# %%
df.Study_Hours_Per_Day.mode()

# %% [markdown]
# **Probiere die Durchschnitts-Statistiken für Variablen deiner Wahl aus**

# %%
# Dein Code hier

# %% [markdown]
# ### Weitere Statistiken
# - `.count()`: Gibt die Anzahl der Beobachtungen zurück
# - `.std()`: Gibt die Standardabweichung an
# - `.quantile(q)`: Gibt den Wert für das eingegeben quantil `q` an
#
# **Probiere die weiteren Statistiken aus**

# %%
# Dein Code hier

# %% [markdown]
# ### Eine schnelle Lösung für alles
#
# Weil die obigen Statistiken oft gemeinsam berechnet werden, gibt es eine Funktion die das für uns bündelt

# %%
df.Study_Hours_Per_Day.describe()

# %% [markdown]
# **Mache das gleiche für eine andere Spalte.** Was passiert wenn du eine kategorische Spalte wählst?

# %%
# Dein Code hier

# %% [markdown]
# ## Korrelationen
#
# Korrelationen sind ein grundlegendes Werkzeug in der Statistik, um den Zusammenhang zwischen zwei Variablen zu untersuchen. Sie geben an, ob und wie stark zwei Größen miteinander in Beziehung stehen.
#
# Die Korrelation wird durch den Korrelationskoeffizienten beschrieben, der Werte zwischen -1 und +1 annehmen kann:
#
# - +1: Perfekte **positive Korrelation** (wenn eine Variable steigt, steigt die andere auch proportional).
# - 0: **Keine Korrelation** (kein erkennbarer Zusammenhang).
# - -1: Perfekte **negative Korrelation** (wenn eine Variable steigt, sinkt die andere proportional).
#
# In der Praxis verwenden wir häufig den **Pearson-Korrelationskoeffizienten**, um lineare Zusammenhänge zu messen. Voraussetzung dafür ist, dass wir zwei numerische Variablen haben.
#
# Für andere Situationen gibt es andere Korrelations-Tests. Diese sind aber nicht so häufig und werden in diesem Kurs nicht betrachtet.
#
# In Python gibt es verschiedene Möglichkeiten, Korrelation zu berechnen:

# %% [markdown]
# Wir sehen, dass längere Lernzeit mit einer höhreren GPA (Grade Point Average) einhergeht. Das entspricht vermutlich unseren Erwartungen. Aber Kausalität können wir damit noch nicht bestätigen.
#
# Hinweis zur Interpretation der `GPA`: Im Gegensatz zum deutschen Schulsystem entspricht eine *höhere* `GPA` einer *besseren* Leistung.

# %%
# Mit pandas wählen wir eine Spalte aus
# Dann bestimmen wir die Funktion die verwendet werden soll (corr())
# Und wählen als Argument für die corr() Funktion die zweite Spalte aus
df.Study_Hours_Per_Day.corr(df.GPA)

# %% [markdown]
# Alternativ können wir den Pearson Korrelationskoeffizienten auch mit `scipy` bestimmen.

# %%
# Wir importieren die Funktion "pearsonr" aus dem "stats" Modul des "scipy" Pakets
from scipy.stats import pearsonr

# %%
# Wir bestimmen das Ergebnis der Korrelation
result = pearsonr(df.Study_Hours_Per_Day, df.GPA)
print(result[0])

# %% [markdown]
# `scipy.stats` lässt uns gleich die Signifkanz des Ergebnisses bestimmen. Das ist der zweite Wert im Tupel. In diesem Fall ist die beobachtete Korrelation statistisch sehr signifikant.
#
# Auch wenn die Korrelation signifikant ist, können wir hier trotzdem noch nicht von Kausalität sprechen. Mehr dazu in der nächsten Lektion. 😊

# %%
result

# %% [markdown]
# **Versuche selbst die Korrelation zwischen zwei Variablen zu bestimmen.**
#
# Hinweis: Korrelationen sind symmetrisch. Es ist also egal, welche Variable du als erstes und welche als zweites nimmst.

# %%
# Dein Code hier

# %% [markdown]
# ### Vorraussetzungen für den Pearson-r Korrelationstest
# Okay, das war recht einfach. Es gibt ein paar Kleinigkeiten, die wir außen vor gelassen haben: Die Voraussetzungen, die einen Pearson-r Test valide machen. Diese nennt man auch oft **parametrische Annahmen**.
#
# 1) Zwei Numerische Variablen
#   - `Study Hours` und `GPA` werden beide in Zahlen angegeben ✅
#
# 2) Linearität
#   - Wir haben noch nicht geprüft ob der vermeintliche Zusammenhang zwischen `Study Hours` und `GPA` linear ist ❌
#
# 3) Ausreißer
#   - Wir haben noch nicht geprüft ob es Ausreißer gibt, die den Zusammenhang verzerren könnten ❌
#
# 4) Normalverteilung
#   - Wir haben noch nicht geprüft ob `Study Hours` und `GPA` normalverteilt sind ❌
#
# Die drei offenen Themen gehen wir im nächsten Abschnitt an.

# %% [markdown]
# # Prüfen parametrischer Annahmen
# ## Linearität
# Pearsons r kann lediglich lineare Zusammenhänge erkennen, ist also schlecht geeignet für Zusammenhänge die eine kurvenform haben.
#
# Beispielsweise ist der Zusammenhang zwischen Temperatur und Wohlbefinden üblicherweise nicht-linear: Viele Menschen fühlen sind bei 20-25 wohl, bei sehr kalten oder sehr heißen Temperaturen aber nicht.
#
# Wir können die Linearität gut per Augenmaß bestimmen, indem wir die Variablen in einem Scatterplot betrachten.

# %% [markdown]
# Tatsächlich beobachten wir einen ansteigenden Trend, ohne Kurven. Es scheint also einen linearen Zusammenhang zwischen den beiden Variablen zu geben.

# %%
df.plot(kind="scatter", x="Study_Hours_Per_Day", y="GPA")

# %% [markdown]
# ## Ausreißeranalyse
# Ausreißer sind solche Datenpunkte, die von der Verteilung der restlichen Datenpunkte stark abweichen. Diese können das Ergebnis verzerren und auf einen Messfehler hinweisen.
#
# Beobachten wir zum Beispiel Datenpunkte die 22 Stunden am Tag lernen, dann ist das vermutlich ein Fehler in der Datenerhebnung und sollte entfernt werden. Aber Achtung: Nur weil ein Datenpunkt ungewöhnlich ist, sollten wir ihn nicht unbedingt entfernen. Ungewöhnliche Dinge passieren, und wenn wir diese nachträglich entfernen (oder anderweitig korrigieren), sind wir vielleicht diejenigen die das Ergebnis verzerren und falsche Rückschlüsse ziehen.
#
# Daher die Faustregel: Ausreißer sollten untersucht werden aber Korrekturen sollten wir nur vornehmen, wenn wir
# a) einen Grund haben zu glauben, dass ein Messfehler vorliegt
# b) unsere statistischen Aussagen nur auf "Mehrheit" einschränken wollen und die extrema bewusst außer Acht lassen wollen.
#
# Wie finden wir also heraus ob ein Datenpunkt ein Ausreißer ist?

# %% [markdown]
# ### Domänenwissen
# Wissen wir, dass bestimmte Messwerte unrealistisch oder unmöglich sind (z.B. 22 oder gar 26 Stunden Lernzeit am Tag) dann können wir guten Gewissens Korrekturen vornehmen.
#
# Solche Eingriffe erfordern lediglich ein gutes Verständnis der Daten & des Erhebungsprozesses sowie ein wenig gesunden Menschenverstands.
#
# Schauen wir uns den Scatterplot oben an, so sehen wir dass die gemessenen Werte nicht unrealistisch oder unmöglich erscheinen.

# %% [markdown]
# ### Visuelle Inspektion
#
# Mit **Scatterplots** oder **Boxplots** können wir die Verteilung unserer Datenpunkte visuell darstellen und somit schnell erkennen, ob einzelne Punkte stark von der üblichen Verteilung abweichen.

# %%
# Wollen wir zwei Variablen auf einmal prüfen eignet sich ein Scatterplot
df.plot(kind="scatter", x="Study_Hours_Per_Day", y="GPA", title="Scatterplot für zwei Variablen");

# %% [markdown]
# Ein **Boxplot** zeigt den **Median** (nicht den Mittelwert, der grüne Strich) an, sowie die **25%- und 75%-Quantile** (die Ränder der Box), auch als **Interquartilbereich (IQR)** bezeichnet. Die **Whiskers** (die "Striche" außerhalb der Box) markieren den **letzten Datenpunkt**, der innerhalb von $1,5 \times \text{IQR}$ vom **25%-Quantil (Q1)** und **75%-Quantil (Q3)** entfernt liegt. Alle Datenpunkte außerhalb dieses Bereichs (also oberhalb von $Q3 + 1,5 \times \text{IQR}$ oder unterhalb von $Q1 - 1,5 \times \text{IQR}$) werden als **Outlier** klassifiziert. Outlier erfordern jedoch **nicht zwingend eine Maßnahme**, sondern sind nur auffällige Punkte, die weiter untersucht werden könnten.
#
# Hilfe bei der Interpretation liefert ein KI-Assistent deiner Wahl, zahlreiche YouTube-Videos oder Websites wie [diese](https://datatab.de/tutorial/boxplot).

# %%
# Wollen wir eine Variable im Detail betrachten, eignet sich ein Boxplot
df.boxplot(column=["Study_Hours_Per_Day", "GPA"])

# %% [markdown]
# ### Wer's genau wissen will: Der Z-Wert
# Der z-Wert gibt an, wie viele Standardabweichungen ein Punkt vom Mittelwert entfernt ist. Somit ist der Z-Wert ein Maß dafür "wie sehr" ein Punkt ein Ausreißer ist. Für normalverteilte Variablen kann man ab einem Z-Wert von 1,5 von einem Ausreißer sprechen.
#
# Lasst uns das für den Maximal- und Minmal-Wert in `GPA` prüfen.

# %%
from re import X
# Das sind die drei Werte die wir brauchen, um den Z-Wert händisch zu bestimmen
x = df.GPA.max()
mean = df.GPA.mean()
std = df.GPA.std()

print(x)
print(mean)
print(std)

# %% [markdown]
# Der Z-Wert ist deutlich über 1,5. Wir könnten hier also von einem Ausreißer sprechen. Ein GPA von 4.0 ist allerdings durchaus möglich und somit meines Erachtens kein Grund für eine Korrektur. Der Z-Wert ist also auch nur ein Indiz oder Richtwert.

# %%
z = (4  - mean) / std
print(z)

# %% [markdown]
# **Versuche das gleiche für den Minmalwert zu machen**

# %% [markdown]
# ## Normalverteilung
# Statistische Tests erfodern oftmals, dass die Variablen die getestet werden sollen, normalverteilt sind. Diese Verteilung ist weit Verbreitet, auch unter dem Namen Gauss Verteilung oder Glockenkurve bekannt.
#
# Wie prüfen wir, ob Variablen normalverteilt sind?

# %% [markdown]
# ### Visuelle Inspektion
# Ein Histogramm gibt uns ein erstes Indiz dafür ob eine Variable normalverteilt ist. In diesem Fall sehen wir die klassische Glockenform. Auf den ersten Blick wirkt die Variable `GPA` also normalverteilt.

# %%
df.GPA.hist()

# %% [markdown]
# ### Empirischer Test
# Normalität kann man auch empirisch testen, geeignet sind dafür der **Shapiro-Wilk Test** und der **Kolgomorov-Smirnov (KS) Test**, benannt nach den Erfindern.
#
#
# **Shapiro Wilk** ist besonders für kleine Stichproben geeignet (<2000 Datenpunkte, aber auch <50)
#
# **KS** erforder größere Datenmengen von mindestens 50, um aussagekräftig zu sein.

# %% [markdown]
# Lasst uns erstmal zählen wie viele Datenpunkte wir haben

# %%
len(df)

# %% [markdown]
# Wir haben exakt 2000 Datenpunkte in unserem Sample. Daher ist der **KS-Test für Normalität** vermutlich der angemessenere. Aber ich zeige euch trotzdem beide:

# %%
from scipy.stats import shapiro

# Perform Shapiro-Wilk test
stat, p_value = shapiro(df.GPA)

print(f"Shapiro-Wilk Test Statistic: {stat}")
print(f"P-Value: {p_value}")

# Interpret result
if p_value > 0.05:
    print("Data is likely normal")
else:
    print("Data is not normal")

# %%
from scipy.stats import kstest

# Perform Kolmogorov-Smirnov test for normality
stat, p_value = kstest(df.GPA, 'norm')

print(f"Kolmogorov-Smirnov Test Statistic: {stat}")
print(f"P-Value: {p_value}")

# Interpret result
if p_value > 0.05:
    print("Data is likely normal")
else:
    print("Data is not normal (reject H0)")

# %% [markdown]
# Beide Tests sagen uns, dass die Verteilung nicht normal ist. Noch deutlicher ist das Ergebnis, wenn wir stattdessen die Variable `Study_Hours` prüfen.
#
# Somit sollten wir mit der Anwendung und Interpretation der **Pearson Korrelation** vorsichtig sein.

# %% [markdown]
# ## Jetzt Du!
# **Prüfe die oben genannten parametrischen Anforderungen für eine oder zwei Variablen deiner Wahl**
#
# Hinweis: Die Variablen müssen numerisch sein.
